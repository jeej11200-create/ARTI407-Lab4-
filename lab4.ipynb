# %% [markdown]
# <a href="https://colab.research.google.com/github/jeej11200-create/ARTI407-Lab4-/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ARTI407 - Lab 4
# Name: Jana Algahtani
# ID: 2230003732

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import data, exposure

# %%
fig = plt.figure(figsize=(10, 7))


fig.add_subplot(2, 1, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
fig.add_subplot(2, 1, 2)
plt.hist(img.ravel(), bins=256)
plt.title('Histogram of Original Image')
plt.xlabel('Gray level')
plt.ylabel('Number of pixels')

plt.show()

# %% [markdown]
# Task 1 (Assessment): Contrast Stretching (3rd and 80th Percentiles)

# %%
p3, p80 = np.percentile(img, (3, 80))
img_rescale = exposure.rescale_intensity(img, in_range=(p3, p80))

fig = plt.figure(figsize=(10, 7))

fig.add_subplot(2, 1, 1)
plt.imshow(img_rescale, cmap='gray')
plt.axis('off')
plt.title('Contrast Stretching 3rd and 80th Percentiles')
# Out:
# Text(0.5, 1.0, 'Contrast Stretching 3rd and 80th Percentiles')

# %%
fig.add_subplot(2, 1, 2)
plt.hist(img_rescale.flat, bins=256, range=(0, 255))
plt.xlabel('Gray level values')
plt.ylabel('Number of pixels')
plt.title('Histogram after Contrast Stretching')

plt.show()

# %% [markdown]
# Task 2: Histogram Equalization

# %%
img_eq = exposure.equalize_hist(img)

fig = plt.figure(figsize=(10, 7))

fig.add_subplot(2, 1, 1)
plt.imshow(img_eq, cmap='gray')
plt.axis('off')
plt.title('Histogram Equalization')
# Out:
# Text(0.5, 1.0, 'Histogram Equalization')

# %%
fig.add_subplot(2, 1, 2)
plt.hist(img_eq.flat, bins=256)
plt.xlabel('Gray level values')
plt.ylabel('Number of pixels')
plt.title('Histogram after Equalization')

plt.show()

# %% [markdown]
# Task 3: Histogram Matching

# %%
from skimage import data
from skimage.exposure import match_histograms

img1 = data.chelsea()
img2 = data.rocket()

# %%
matched = match_histograms(img1, img2, channel_axis=-1)

# %%
fig = plt.figure(figsize=(12, 8))

fig.add_subplot(1, 3, 1)
plt.imshow(img1)
plt.title('Original Image (Chelsea)')
plt.axis('off')

fig.add_subplot(1, 3, 2)
plt.imshow(img2)
plt.title('Reference Image (Rocket)')
plt.axis('off')

fig.add_subplot(1, 3, 3)
plt.imshow(matched.astype('uint8'))
plt.title('Matched Image')
plt.axis('off')

plt.show()
